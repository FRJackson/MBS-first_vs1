# %% [markdown]
# <a href="https://colab.research.google.com/github/FRJackson/MBS-first_vs1/blob/main/mbs_data_upload.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 kB 3.3 MB/s eta 0:00:00
# Mounted at /content/drive

# %%
# !pip -q install supabase
from google.colab import drive
drive.mount('/content/drive')

import os, pandas as pd, numpy as np, csv
from supabase import create_client, Client

DATA_FOLDER = "/content/drive/MyDrive/fre-crt-2025-07-2025-09"
url = "https://accqwjvmfcgzqhyzkmqn.supabase.co"
key = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImFjY3F3anZtZmNnenFoeXprbXFuIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NjAwOTY0NzEsImV4cCI6MjA3NTY3MjQ3MX0.4oncORXiSE7j0PygApUL1U4KTgsdzpIbLI8Jdn5QWhk"
supabase: Client = create_client(url, key)

CHUNK_READ = 20000
BATCH_SIZE = 500

headers = [
  "period","reference_pool_number","loan_identifier","amortization_type","seller_name",
  "property_state","postal_code","msa","first_payment_date","maturity_date",
  "original_loan_term","original_interest_rate","original_upb","upb_at_issuance",
  "loan_purpose","channel","property_type","number_of_units","occupancy_status",
  "number_of_borrowers","first_time_homebuyer_indicator","prepayment_penalty_indicator",
  "credit_score","original_loan_to_value_ltv","original_combined_loan_to_value_cltv",
  "original_debt_to_income_dti_ratio","mortgage_insurance_percentage_mi_percent",
  "updated_credit_score_at_issuance","special_eligibility_program","mortgage_insurance_type",
  "filler","disaster_grace_period","servicer_name","loan_age",
  "remaining_months_to_legal_maturity","adjusted_remaining_months_to_maturity_rmm",
  "current_loan_delinquency_status","payment_history","current_interest_rate",
  "current_actual_upb","current_interest_bearing_upb",
  "upb_at_time_of_removal_from_the_reference_pool","zero_balance_code",
  "zero_balance_effective_date","underwriting_defect_and_major_servicing_defect_settlement_date",
  "modification_flag","delinquency_due_to_disaster",
  "due_date_of_last_paid_installment_ddlpi","bankruptcy_flag","date_referred_to_foreclosure",
  "net_sales_proceeds","mi_credit","taxes_and_insurance","legal_costs",
  "maintenance_and_preservation_costs","bankruptcy_cramdown_costs",
  "miscellaneous_expenses","miscellaneous_credits","mortgage_insurance_cancellation_indicator",
  "estimated_loan_to_value_ltv_quarterly","forecast_standard_deviation_fsd",
  "updated_credit_score_1_quarterly","updated_credit_score_2_quarterly",
  "number_of_modifications","modification_program","modification_type",
  "modification_first_payment_date","modification_debt_to_income_ratio",
  "total_capitalized_amount","interest_rate_step_indicator",
  "first_step_rate_adjustment_date","first_step_rate","second_step_rate_adjustment_date",
  "second_step_rate","third_step_rate_adjustment_date","third_step_rate",
  "fourth_step_rate_adjustment_date","fourth_step_rate",
  "fifth_step_rate_adjustment_date","fifth_step_rate","delinquent_accrued_interest",
  "modification_costs","updated_credit_score_3_quarterly","property_valuation_method",
  "group_number","enhanced_relief_refi_indicator","borrower_assistance_plan",
  "payment_deferral_flag","distressed_principal_balance_flag",
  "temporary_subsidy_buydown_plan_type"
]

def normalize(df):
  for c in df.columns:
    df[c] = df[c].astype(str).str.strip()
  df = df.replace({"": None})
  s = "current_loan_delinquency_status"
  if s in df.columns:
    x = df[s].fillna("")
    isnum = x.str.fullmatch(r"\d+")
    df.loc[isnum, s] = x[isnum].str.zfill(2)
    df.loc[~isnum & (x==""), s] = None
    df.loc[~isnum & (x!=""), s] = x[~isnum & (x!="")].str.upper()
  return df

def list_files(root):
  exts = {'.txt','.text','.dat','.csv'}
  out = []
  for r,_,fns in os.walk(root):
    for fn in sorted(fns):
      if fn.startswith('.'): continue
      ext = os.path.splitext(fn)[1].lower()
      if ext in exts or ext=='': out.append(os.path.join(r,fn))
  return out

files = list_files(DATA_FOLDER)
print(f"Found {len(files)} files under {DATA_FOLDER}")

uploaded_total = 0
for path in files:
  print(f"Processing: {os.path.relpath(path, DATA_FOLDER)}")
  try:
    rdr = pd.read_csv(
      path,
      sep='|',
      header=None,
      dtype=str,
      engine="python",
      chunksize=CHUNK_READ,
      quoting=csv.QUOTE_NONE,
      on_bad_lines='skip',
      keep_default_na=False
    )
    for chunk in rdr:
      cols = chunk.shape[1]
      need = len(headers)
      if cols < need:
        for j in range(need - cols):
          chunk[cols + j] = None
      elif cols > need:
        chunk = chunk.iloc[:, :need]
      chunk.columns = headers
      chunk = normalize(chunk)
      for i in range(0, len(chunk), BATCH_SIZE):
        recs = chunk.iloc[i:i+BATCH_SIZE].to_dict("records")
        supabase.table("freddie_mac_crt_raw_2023_2023").insert(recs, returning="minimal").execute()
        uploaded_total += len(recs)
    print("✓ uploaded")
  except Exception as e:
    print(f"✗ failed: {e}")

print(f"Done. Uploaded {uploaded_total} rows.")
# Out:
# Found 1 files under /content/drive/MyDrive/fre-crt-2025-07-2025-09
# Processing: 20SP01_20250701_lld.txt
# ✓ uploaded
# Done. Uploaded 168092 rows.

# %%
# !pip -q install pyarrow

from google.colab import drive
drive.mount('/content/drive')

import os, pandas as pd, numpy as np, csv, re
import pyarrow as pa
import pyarrow.parquet as pq

# ====== 配置区域 ======
DATA_FOLDER = "/content/drive/MyDrive/fre-crt-2025-07-2025-09"
OUTPUT_PATH = "/content/drive/MyDrive/fre-crt-2025-07-2025-09-all.parquet"

CHUNK_READ = 20000   # 每次读文件的行数（跟你原来一样）
# ====================

headers = [
    "period","reference_pool_number","loan_identifier","amortization_type","seller_name",
    "property_state","postal_code","msa","first_payment_date","maturity_date",
    "original_loan_term","original_interest_rate","original_upb","upb_at_issuance",
    "loan_purpose","channel","property_type","number_of_units","occupancy_status",
    "number_of_borrowers","first_time_homebuyer_indicator","prepayment_penalty_indicator",
    "credit_score","original_loan_to_value_ltv","original_combined_loan_to_value_cltv",
    "original_debt_to_income_dti_ratio","mortgage_insurance_percentage_mi_percent",
    "updated_credit_score_at_issuance","special_eligibility_program","mortgage_insurance_type",
    "filler","disaster_grace_period","servicer_name","loan_age",
    "remaining_months_to_legal_maturity","adjusted_remaining_months_to_maturity_rmm",
    "current_loan_delinquency_status","payment_history","current_interest_rate",
    "current_actual_upb","current_interest_bearing_upb",
    "upb_at_time_of_removal_from_the_reference_pool","zero_balance_code",
    "zero_balance_effective_date","underwriting_defect_and_major_servicing_defect_settlement_date",
    "modification_flag","delinquency_due_to_disaster",
    "due_date_of_last_paid_installment_ddlpi","bankruptcy_flag","date_referred_to_foreclosure",
    "net_sales_proceeds","mi_credit","taxes_and_insurance","legal_costs",
    "maintenance_and_preservation_costs","bankruptcy_cramdown_costs",
    "miscellaneous_expenses","miscellaneous_credits","mortgage_insurance_cancellation_indicator",
    "estimated_loan_to_value_ltv_quarterly","forecast_standard_deviation_fsd",
    "updated_credit_score_1_quarterly","updated_credit_score_2_quarterly",
    "number_of_modifications","modification_program","modification_type",
    "modification_first_payment_date","modification_debt_to_income_ratio",
    "total_capitalized_amount","interest_rate_step_indicator",
    "first_step_rate_adjustment_date","first_step_rate","second_step_rate_adjustment_date",
    "second_step_rate","third_step_rate_adjustment_date","third_step_rate",
    "fourth_step_rate_adjustment_date","fourth_step_rate",
    "fifth_step_rate_adjustment_date","fifth_step_rate","delinquent_accrued_interest",
    "modification_costs","updated_credit_score_3_quarterly","property_valuation_method",
    "group_number","enhanced_relief_refi_indicator","borrower_assistance_plan",
    "payment_deferral_flag","distressed_principal_balance_flag",
    "temporary_subsidy_buydown_plan_type"
]

def normalize(df: pd.DataFrame) -> pd.DataFrame:
    # 全部转成字符串 & 去掉首尾空格
    for c in df.columns:
        df[c] = df[c].astype(str).str.strip()
    # 空字符串统一为 None
    df = df.replace({"": None})

    # 特殊处理 current_loan_delinquency_status 字段
    s = "current_loan_delinquency_status"
    if s in df.columns:
        x = df[s].fillna("")
        isnum = x.str.fullmatch(r"\d+")
        # 数字 → 左侧补零到 2 位
        df.loc[isnum, s] = x[isnum].str.zfill(2)
        # 空字符串 → None
        df.loc[~isnum & (x == ""), s] = None
        # 其他非空非数字 → 转大写字符串
        df.loc[~isnum & (x != ""), s] = x[~isnum & (x != "")].str.upper()
    return df

def list_files(root):
    exts = {'.txt', '.text', '.dat', '.csv'}
    out = []
    for r, _, fns in os.walk(root):
        for fn in sorted(fns):
            if fn.startswith('.'):
                continue
            ext = os.path.splitext(fn)[1].lower()
            if ext in exts or ext == '':
                out.append(os.path.join(r, fn))
    return out

# 如果之前跑过，先删掉旧的输出文件，避免 schema 冲突
if os.path.exists(OUTPUT_PATH):
    os.remove(OUTPUT_PATH)

files = list_files(DATA_FOLDER)
print(f"Found {len(files)} files under {DATA_FOLDER}")

writer = None
total_rows = 0

for path in files:
    print(f"\nProcessing: {os.path.relpath(path, DATA_FOLDER)}")
    try:
        rdr = pd.read_csv(
            path,
            sep='|',
            header=None,
            dtype=str,
            engine="python",
            chunksize=CHUNK_READ,
            quoting=csv.QUOTE_NONE,
            on_bad_lines='skip',
            keep_default_na=False
        )

        for chunk in rdr:
            cols = chunk.shape[1]
            need = len(headers)

            # 列数不足 → 补 None；列数太多 → 截断
            if cols < need:
                for j in range(need - cols):
                    chunk[cols + j] = None
            elif cols > need:
                chunk = chunk.iloc[:, :need]

            chunk.columns = headers
            chunk = normalize(chunk)

            # 转成 Arrow Table
            table = pa.Table.from_pandas(chunk, preserve_index=False)

            # 初始化 ParquetWriter（第一次用当前 schema）
            if writer is None:
                writer = pq.ParquetWriter(
                    OUTPUT_PATH,
                    table.schema,
                    compression="snappy"
                )

            writer.write_table(table)
            total_rows += table.num_rows

        print("✓ merged into parquet")

    except Exception as e:
        print(f"✗ failed: {e}")

# 关闭 writer
if writer is not None:
    writer.close()

print(f"\nDone. Total merged rows: {total_rows}")
print(f"Output file: {OUTPUT_PATH}")
# Out:
# Mounted at /content/drive
# Found 6 files under /content/drive/MyDrive/fre-crt-2025-07-2025-09
#
# Processing: 20SP01_20250701_lld.txt
# ✓ merged into parquet
#
# Processing: 20SP01_20250801_lld.txt
# ✓ merged into parquet
#
# Processing: 20SP01_20250901_lld.txt
# ✓ merged into parquet
#
# Processing: 21SP03_20250701_lld.txt
# ✗ failed: Table schema does not match schema used to create file:
# table:
# period: string
# reference_pool_number: string
# loan_identifier: string
# amortization_type: string
# seller_name: string
# property_state: string
# postal_code: string
# msa: string
# first_payment_date: string
# maturity_date: string
# original_loan_term: string
# original_interest_rate: string
# original_upb: string
# upb_at_issuance: string
# loan_purpose: string
# channel: string
# property_type: string
# number_of_units: string
# occupancy_status: string
# number_of_borrowers: string
# first_time_homebuyer_indicator: string
# prepayment_penalty_indicator: string
# credit_score: string
# original_loan_to_value_ltv: string
# original_combined_loan_to_value_cltv: string
# original_debt_to_income_dti_ratio: string
# mortgage_insurance_percentage_mi_percent: string
# updated_credit_score_at_issuance: string
# special_eligibility_program: string
# mortgage_insurance_type: string
# filler: null
# disaster_grace_period: null
# servicer_name: string
# loan_age: string
# remaining_months_to_legal_maturity: string
# adjusted_remaining_months_to_maturity_rmm: string
# current_loan_delinquency_status: string
# payment_history: string
# current_interest_rate: string
# current_actual_upb: string
# current_interest_bearing_upb: string
# upb_at_time_of_removal_from_the_reference_pool: string
# zero_balance_code: string
# zero_balance_effective_date: string
# underwriting_defect_and_major_servicing_defect_settlement_date: string
# modification_flag: string
# delinquency_due_to_disaster: null
# due_date_of_last_paid_installment_ddlpi: string
# bankruptcy_flag: string
# date_referred_to_foreclosure: string
# net_sales_proceeds: string
# mi_credit: string
# taxes_and_insurance: string
# legal_costs: string
# maintenance_and_preservation_costs: string
# bankruptcy_cramdown_costs: string
# miscellaneous_expenses: string
# miscellaneous_credits: string
# mortgage_insurance_cancellation_indicator: string
# estimated_loan_to_value_ltv_quarterly: string
# forecast_standard_deviation_fsd: null
# updated_credit_score_1_quarterly: string
# updated_credit_score_2_quarterly: string
# number_of_modifications: string
# modification_program: string
# modification_type: string
# modification_first_payment_date: string
# modification_debt_to_income_ratio: string
# total_capitalized_amount: string
# interest_rate_step_indicator: string
# first_step_rate_adjustment_date: null
# first_step_rate: null
# second_step_rate_adjustment_date: null
# second_step_rate: null
# third_step_rate_adjustment_date: null
# third_step_rate: null
# fourth_step_rate_adjustment_date: null
# fourth_step_rate: null
# fifth_step_rate_adjustment_date: null
# fifth_step_rate: null
# delinquent_accrued_interest: string
# modification_costs: string
# updated_credit_score_3_quarterly: null
# property_valuation_method: string
# group_number: string
# enhanced_relief_refi_indicator: string
# borrower_assistance_plan: string
# payment_deferral_flag: string
# distressed_principal_balance_flag: string
# temporary_subsidy_buydown_plan_type: string
# -- schema metadata --
# pandas: '{"index_columns": [], "column_indexes": [], "columns": [{"name":' + 13201 vs.
# file:
# period: string
# reference_pool_number: string
# loan_identifier: string
# amortization_type: string
# seller_name: string
# property_state: string
# postal_code: string
# msa: string
# first_payment_date: string
# maturity_date: string
# original_loan_term: string
# original_interest_rate: string
# original_upb: string
# upb_at_issuance: string
# loan_purpose: string
# channel: string
# property_type: string
# number_of_units: string
# occupancy_status: string
# number_of_borrowers: string
# first_time_homebuyer_indicator: string
# prepayment_penalty_indicator: string
# credit_score: string
# original_loan_to_value_ltv: string
# original_combined_loan_to_value_cltv: string
# original_debt_to_income_dti_ratio: string
# mortgage_insurance_percentage_mi_percent: string
# updated_credit_score_at_issuance: string
# special_eligibility_program: string
# mortgage_insurance_type: string
# filler: null
# disaster_grace_period: null
# servicer_name: string
# loan_age: string
# remaining_months_to_legal_maturity: string
# adjusted_remaining_months_to_maturity_rmm: string
# current_loan_delinquency_status: string
# payment_history: string
# current_interest_rate: string
# current_actual_upb: string
# current_interest_bearing_upb: string
# upb_at_time_of_removal_from_the_reference_pool: string
# zero_balance_code: string
# zero_balance_effective_date: string
# underwriting_defect_and_major_servicing_defect_settlement_date: string
# modification_flag: string
# delinquency_due_to_disaster: string
# due_date_of_last_paid_installment_ddlpi: string
# bankruptcy_flag: string
# date_referred_to_foreclosure: string
# net_sales_proceeds: string
# mi_credit: string
# taxes_and_insurance: string
# legal_costs: string
# maintenance_and_preservation_costs: string
# bankruptcy_cramdown_costs: string
# miscellaneous_expenses: string
# miscellaneous_credits: string
# mortgage_insurance_cancellation_indicator: string
# estimated_loan_to_value_ltv_quarterly: string
# forecast_standard_deviation_fsd: null
# updated_credit_score_1_quarterly: string
# updated_credit_score_2_quarterly: string
# number_of_modifications: string
# modification_program: string
# modification_type: string
# modification_first_payment_date: string
# modification_debt_to_income_ratio: string
# total_capitalized_amount: string
# interest_rate_step_indicator: string
# first_step_rate_adjustment_date: null
# first_step_rate: null
# second_step_rate_adjustment_date: null
# second_step_rate: null
# third_step_rate_adjustment_date: null
# third_step_rate: null
# fourth_step_rate_adjustment_date: null
# fourth_step_rate: null
# fifth_step_rate_adjustment_date: null
# fifth_step_rate: null
# delinquent_accrued_interest: string
# modification_costs: string
# updated_credit_score_3_quarterly: null
# property_valuation_method: string
# group_number: string
# enhanced_relief_refi_indicator: string
# borrower_assistance_plan: string
# payment_deferral_flag: string
# distressed_principal_balance_flag: string
# temporary_subsidy_buydown_plan_type: string
# -- schema metadata --
# pandas: '{"index_columns": [], "column_indexes": [], "columns": [{"name":' + 13203
#
# Processing: 21SP03_20250801_lld.txt
# ✗ failed: Table schema does not match schema used to create file:
# table:
# period: string
# reference_pool_number: string
# loan_identifier: string
# amortization_type: string
# seller_name: string
# property_state: string
# postal_code: string
# msa: string
# first_payment_date: string
# maturity_date: string
# original_loan_term: string
# original_interest_rate: string
# original_upb: string
# upb_at_issuance: string
# loan_purpose: string
# channel: string
# property_type: string
# number_of_units: string
# occupancy_status: string
# number_of_borrowers: string
# first_time_homebuyer_indicator: string
# prepayment_penalty_indicator: string
# credit_score: string
# original_loan_to_value_ltv: string
# original_combined_loan_to_value_cltv: string
# original_debt_to_income_dti_ratio: string
# mortgage_insurance_percentage_mi_percent: string
# updated_credit_score_at_issuance: string
# special_eligibility_program: string
# mortgage_insurance_type: string
# filler: null
# disaster_grace_period: null
# servicer_name: string
# loan_age: string
# remaining_months_to_legal_maturity: string
# adjusted_remaining_months_to_maturity_rmm: string
# current_loan_delinquency_status: string
# payment_history: string
# current_interest_rate: string
# current_actual_upb: string
# current_interest_bearing_upb: string
# upb_at_time_of_removal_from_the_reference_pool: string
# zero_balance_code: string
# zero_balance_effective_date: string
# underwriting_defect_and_major_servicing_defect_settlement_date: string
# modification_flag: string
# delinquency_due_to_disaster: null
# due_date_of_last_paid_installment_ddlpi: string
# bankruptcy_flag: string
# date_referred_to_foreclosure: string
# net_sales_proceeds: string
# mi_credit: string
# taxes_and_insurance: string
# legal_costs: string
# maintenance_and_preservation_costs: string
# bankruptcy_cramdown_costs: string
# miscellaneous_expenses: string
# miscellaneous_credits: string
# mortgage_insurance_cancellation_indicator: string
# estimated_loan_to_value_ltv_quarterly: string
# forecast_standard_deviation_fsd: null
# updated_credit_score_1_quarterly: string
# updated_credit_score_2_quarterly: string
# number_of_modifications: string
# modification_program: string
# modification_type: string
# modification_first_payment_date: string
# modification_debt_to_income_ratio: string
# total_capitalized_amount: string
# interest_rate_step_indicator: string
# first_step_rate_adjustment_date: null
# first_step_rate: null
# second_step_rate_adjustment_date: null
# second_step_rate: null
# third_step_rate_adjustment_date: null
# third_step_rate: null
# fourth_step_rate_adjustment_date: null
# fourth_step_rate: null
# fifth_step_rate_adjustment_date: null
# fifth_step_rate: null
# delinquent_accrued_interest: string
# modification_costs: string
# updated_credit_score_3_quarterly: null
# property_valuation_method: string
# group_number: string
# enhanced_relief_refi_indicator: string
# borrower_assistance_plan: string
# payment_deferral_flag: string
# distressed_principal_balance_flag: string
# temporary_subsidy_buydown_plan_type: string
# -- schema metadata --
# pandas: '{"index_columns": [], "column_indexes": [], "columns": [{"name":' + 13201 vs.
# file:
# period: string
# reference_pool_number: string
# loan_identifier: string
# amortization_type: string
# seller_name: string
# property_state: string
# postal_code: string
# msa: string
# first_payment_date: string
# maturity_date: string
# original_loan_term: string
# original_interest_rate: string
# original_upb: string
# upb_at_issuance: string
# loan_purpose: string
# channel: string
# property_type: string
# number_of_units: string
# occupancy_status: string
# number_of_borrowers: string
# first_time_homebuyer_indicator: string
# prepayment_penalty_indicator: string
# credit_score: string
# original_loan_to_value_ltv: string
# original_combined_loan_to_value_cltv: string
# original_debt_to_income_dti_ratio: string
# mortgage_insurance_percentage_mi_percent: string
# updated_credit_score_at_issuance: string
# special_eligibility_program: string
# mortgage_insurance_type: string
# filler: null
# disaster_grace_period: null
# servicer_name: string
# loan_age: string
# remaining_months_to_legal_maturity: string
# adjusted_remaining_months_to_maturity_rmm: string
# current_loan_delinquency_status: string
# payment_history: string
# current_interest_rate: string
# current_actual_upb: string
# current_interest_bearing_upb: string
# upb_at_time_of_removal_from_the_reference_pool: string
# zero_balance_code: string
# zero_balance_effective_date: string
# underwriting_defect_and_major_servicing_defect_settlement_date: string
# modification_flag: string
# delinquency_due_to_disaster: string
# due_date_of_last_paid_installment_ddlpi: string
# bankruptcy_flag: string
# date_referred_to_foreclosure: string
# net_sales_proceeds: string
# mi_credit: string
# taxes_and_insurance: string
# legal_costs: string
# maintenance_and_preservation_costs: string
# bankruptcy_cramdown_costs: string
# miscellaneous_expenses: string
# miscellaneous_credits: string
# mortgage_insurance_cancellation_indicator: string
# estimated_loan_to_value_ltv_quarterly: string
# forecast_standard_deviation_fsd: null
# updated_credit_score_1_quarterly: string
# updated_credit_score_2_quarterly: string
# number_of_modifications: string
# modification_program: string
# modification_type: string
# modification_first_payment_date: string
# modification_debt_to_income_ratio: string
# total_capitalized_amount: string
# interest_rate_step_indicator: string
# first_step_rate_adjustment_date: null
# first_step_rate: null
# second_step_rate_adjustment_date: null
# second_step_rate: null
# third_step_rate_adjustment_date: null
# third_step_rate: null
# fourth_step_rate_adjustment_date: null
# fourth_step_rate: null
# fifth_step_rate_adjustment_date: null
# fifth_step_rate: null
# delinquent_accrued_interest: string
# modification_costs: string
# updated_credit_score_3_quarterly: null
# property_valuation_method: string
# group_number: string
# enhanced_relief_refi_indicator: string
# borrower_assistance_plan: string
# payment_deferral_flag: string
# distressed_principal_balance_flag: string
# temporary_subsidy_buydown_plan_type: string
# -- schema metadata --
# pandas: '{"index_columns": [], "column_indexes": [], "columns": [{"name":' + 13203
#
# Processing: 21SP03_20250901_lld.txt
# ✗ failed: Table schema does not match schema used to create file:
# table:
# period: string
# reference_pool_number: string
# loan_identifier: string
# amortization_type: string
# seller_name: string
# property_state: string
# postal_code: string
# msa: string
# first_payment_date: string
# maturity_date: string
# original_loan_term: string
# original_interest_rate: string
# original_upb: string
# upb_at_issuance: string
# loan_purpose: string
# channel: string
# property_type: string
# number_of_units: string
# occupancy_status: string
# number_of_borrowers: string
# first_time_homebuyer_indicator: string
# prepayment_penalty_indicator: string
# credit_score: string
# original_loan_to_value_ltv: string
# original_combined_loan_to_value_cltv: string
# original_debt_to_income_dti_ratio: string
# mortgage_insurance_percentage_mi_percent: string
# updated_credit_score_at_issuance: string
# special_eligibility_program: string
# mortgage_insurance_type: string
# filler: null
# disaster_grace_period: null
# servicer_name: string
# loan_age: string
# remaining_months_to_legal_maturity: string
# adjusted_remaining_months_to_maturity_rmm: string
# current_loan_delinquency_status: string
# payment_history: string
# current_interest_rate: string
# current_actual_upb: string
# current_interest_bearing_upb: string
# upb_at_time_of_removal_from_the_reference_pool: string
# zero_balance_code: string
# zero_balance_effective_date: string
# underwriting_defect_and_major_servicing_defect_settlement_date: string
# modification_flag: string
# delinquency_due_to_disaster: null
# due_date_of_last_paid_installment_ddlpi: string
# bankruptcy_flag: string
# date_referred_to_foreclosure: string
# net_sales_proceeds: string
# mi_credit: string
# taxes_and_insurance: string
# legal_costs: string
# maintenance_and_preservation_costs: string
# bankruptcy_cramdown_costs: string
# miscellaneous_expenses: string
# miscellaneous_credits: string
# mortgage_insurance_cancellation_indicator: string
# estimated_loan_to_value_ltv_quarterly: string
# forecast_standard_deviation_fsd: null
# updated_credit_score_1_quarterly: string
# updated_credit_score_2_quarterly: string
# number_of_modifications: string
# modification_program: string
# modification_type: string
# modification_first_payment_date: string
# modification_debt_to_income_ratio: string
# total_capitalized_amount: string
# interest_rate_step_indicator: string
# first_step_rate_adjustment_date: null
# first_step_rate: null
# second_step_rate_adjustment_date: null
# second_step_rate: null
# third_step_rate_adjustment_date: null
# third_step_rate: null
# fourth_step_rate_adjustment_date: null
# fourth_step_rate: null
# fifth_step_rate_adjustment_date: null
# fifth_step_rate: null
# delinquent_accrued_interest: string
# modification_costs: string
# updated_credit_score_3_quarterly: null
# property_valuation_method: string
# group_number: string
# enhanced_relief_refi_indicator: string
# borrower_assistance_plan: string
# payment_deferral_flag: string
# distressed_principal_balance_flag: string
# temporary_subsidy_buydown_plan_type: string
# -- schema metadata --
# pandas: '{"index_columns": [], "column_indexes": [], "columns": [{"name":' + 13201 vs.
# file:
# period: string
# reference_pool_number: string
# loan_identifier: string
# amortization_type: string
# seller_name: string
# property_state: string
# postal_code: string
# msa: string
# first_payment_date: string
# maturity_date: string
# original_loan_term: string
# original_interest_rate: string
# original_upb: string
# upb_at_issuance: string
# loan_purpose: string
# channel: string
# property_type: string
# number_of_units: string
# occupancy_status: string
# number_of_borrowers: string
# first_time_homebuyer_indicator: string
# prepayment_penalty_indicator: string
# credit_score: string
# original_loan_to_value_ltv: string
# original_combined_loan_to_value_cltv: string
# original_debt_to_income_dti_ratio: string
# mortgage_insurance_percentage_mi_percent: string
# updated_credit_score_at_issuance: string
# special_eligibility_program: string
# mortgage_insurance_type: string
# filler: null
# disaster_grace_period: null
# servicer_name: string
# loan_age: string
# remaining_months_to_legal_maturity: string
# adjusted_remaining_months_to_maturity_rmm: string
# current_loan_delinquency_status: string
# payment_history: string
# current_interest_rate: string
# current_actual_upb: string
# current_interest_bearing_upb: string
# upb_at_time_of_removal_from_the_reference_pool: string
# zero_balance_code: string
# zero_balance_effective_date: string
# underwriting_defect_and_major_servicing_defect_settlement_date: string
# modification_flag: string
# delinquency_due_to_disaster: string
# due_date_of_last_paid_installment_ddlpi: string
# bankruptcy_flag: string
# date_referred_to_foreclosure: string
# net_sales_proceeds: string
# mi_credit: string
# taxes_and_insurance: string
# legal_costs: string
# maintenance_and_preservation_costs: string
# bankruptcy_cramdown_costs: string
# miscellaneous_expenses: string
# miscellaneous_credits: string
# mortgage_insurance_cancellation_indicator: string
# estimated_loan_to_value_ltv_quarterly: string
# forecast_standard_deviation_fsd: null
# updated_credit_score_1_quarterly: string
# updated_credit_score_2_quarterly: string
# number_of_modifications: string
# modification_program: string
# modification_type: string
# modification_first_payment_date: string
# modification_debt_to_income_ratio: string
# total_capitalized_amount: string
# interest_rate_step_indicator: string
# first_step_rate_adjustment_date: null
# first_step_rate: null
# second_step_rate_adjustment_date: null
# second_step_rate: null
# third_step_rate_adjustment_date: null
# third_step_rate: null
# fourth_step_rate_adjustment_date: null
# fourth_step_rate: null
# fifth_step_rate_adjustment_date: null
# fifth_step_rate: null
# delinquent_accrued_interest: string
# modification_costs: string
# updated_credit_score_3_quarterly: null
# property_valuation_method: string
# group_number: string
# enhanced_relief_refi_indicator: string
# borrower_assistance_plan: string
# payment_deferral_flag: string
# distressed_principal_balance_flag: string
# temporary_subsidy_buydown_plan_type: string
# -- schema metadata --
# pandas: '{"index_columns": [], "column_indexes": [], "columns": [{"name":' + 13203
#
# Done. Total merged rows: 504276
# Output file: /content/drive/MyDrive/fre-crt-2025-07-2025-09-all.parquet
